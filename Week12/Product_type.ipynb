# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgeniaKantor/DI-Bootcamp/blob/main/Week12/Product_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import google.generativeai as genai
from google.colab import userdata
import os

# Load the dataset
df = pd.read_excel('df_combined.xlsx')

# Used to securely store your API key
GOOGLE_API_KEY = userdata.get('gemini_key')

# Configure the generative AI client
genai.configure(api_key=GOOGLE_API_KEY)

# Assign the API key to an environment variable
os.environ['GOOGLE_API_KEY'] = GOOGLE_API_KEY

# Load the generative model
model = genai.GenerativeModel('gemini-pro')

# Define the chunk size
chunk_size = 10

# Split the 'product_title' column into chunks of 10 titles each
title_chunks = np.array_split(df['product_title'], len(df) // chunk_size + 1)

# List of standardized product types
product_types_list = [
    "Acne Patches", "Acne Treatment", "After Shave", "Anti Chafe", "Anti-aging Cream",
    "Anti-aging Mask", "Anti-aging Serum", "Beauty Tools", "Body Cream", "Body Lotion",
    "Body Powder", "Body Scrub", "Body Soap", "Body Wash", "Collagen Powder",
    "Exfoliating Mask", "Eye Cream", "Eye Gel", "Eye Mask", "Eye Patches", "Face Cleanser", "Face Cream",
    "Face Exfoliator", "Face Foam", "Face Mask", "Face Mist", "Face Moisturizer",
    "Face Oil", "Face Patches", "Face Scrub", "Face Serum", "Face Soap", "Face Sunscreen",
    "Face Toner", "Face Wash", "Face Wipes", "Hair Care", "Hair Removal", "Hand Cream",
    "Hand Soap", "Head Band", "Kids Care", "Lip Balm", "Lip Mask", "Lip Oil",
    "Makeup Remover", "Neck Cream", "Sheet Mask", "Skincare Set",
    "Sunscreen Cream", "Sunscreen Spray", "Tanning Lotion"
]

# Initialize an empty list to store DataFrames
dfs = []

# Function to clean and standardize product titles
def clean_title(title):
    return title.strip().lower().replace('&amp;', '&').replace(',', '').replace('|', '')

# Iterate over title chunks and generate DataFrames
for i, titles_chunk in enumerate(title_chunks):
    # Clean and standardize titles
    cleaned_titles = titles_chunk.apply(clean_title)

    # Construct the query for the chunk
    query = "From the titles:\n"
    for title in cleaned_titles:
        query += f"{title}\n"
    query += "\nextract product type from each title, use only one of the following types:\n"
    query += ', '.join(product_types_list)
    query += ". The result must be in a dataframe with two columns: 'product_title' and 'product_type'."

    # Generate content using Gemini
    response = model.generate_content(query)

    # Extract the text content from the response
    try:
        response_content = response.candidates[0].content.parts[0].text
    except (IndexError, AttributeError):
        raise ValueError("Unexpected response format from the generative model.")

    # Print the response
    print(f"Response for Chunk {i+1}:\n{response_content}\n")

    # Check if the response content is in table format
    if '| product_title' in response_content:
        # Parse the table into a DataFrame
        response_lines = response_content.split('\n')
        headers = response_lines[0].split('|')[1:-1]  # Extract column headers
        rows = [line.split('|')[1:-1] for line in response_lines[2:] if line.strip()]  # Extract rows

        # Ensure all rows have the same number of columns as headers
        rows = [row[:len(headers)] for row in rows]

        # Create DataFrame
        response_df = pd.DataFrame(rows, columns=headers)

        # Clean column names
        response_df.columns = response_df.columns.str.strip().str.replace('&amp;', '&')

        # Print the content of response_df
        print(f"Content of response_df:\n{response_df}\n")

        # Check if DataFrame is not empty
        if not response_df.empty:
            # Extract only the necessary columns: product_title and product_type
            response_df = response_df[['product_title', 'product_type']]

            # Clean and standardize product titles
            response_df['product_title'] = response_df['product_title'].apply(clean_title)

            # Append the DataFrame to the list
            dfs.append(response_df)
        else:
            print("DataFrame is empty. Skipping.")

# Concatenate DataFrames
final_df_new = pd.concat(dfs, ignore_index=True)
# Out:
# Response for Chunk 1:
# ```
#                                 product_title product_type
# 0  under eye patches - 60 pcs - 24k gold eye mask- puffy eyes & ...  Eye Patches
# 1  pimple patches for face hydrocolloid acne patches cute star ...  Acne Patches
# 2                                 sleeping lip mask nourish & ...    Lip Mask
# 3  glow recipe pha + bha face toner - skin care toner pore mini...  Face Toner
# 4  under eye patches (30 pairs) gold eye mask and hyaluronic a...  Eye Patches
# 5  bum cream moisturizing body cream body skin repair bum crea...  Body Cream
# 6  good molecules hyaluronic acid serum - hydrating non-greasy f...  Face Serum
# 7  bubble skincare slam dunk face moisturizer - hydrating face...  Face Moisturizer
# 8  good molecules yerba mate wake up eye gel - yerba mate hyal...  Eye Gel
# 9  eos shea better body lotion- coconut waters 24-hour moistur...  Body Lotion
# ```
#
# Response for Chunk 2:
# | product_title | product_type |
# | - | - |
# | tree hut vitamin c shea sugar scrub 18 oz ultra hydrating and exfoliating scrub for nourishing essential body care | Body Scrub |
# | ice roller for face and eye ice face rollerfacial beauty ice roller skin care tools ice facial cube gua sha face massage silicone ice mold for face beauty (purple) | Beauty Tools |
# | mario badescu facial spray with aloe herbs and rose water for all skin types face mist that hydrates rejuvenates & clarifies | Face Mist |
# | cerave skin renewing night cream  niacinamide peptide complex and hyaluronic acid moisturizer for face  1.7 ounce packaging may vary | Face Cream |
# | hero cosmetics mighty patch™ original patch - hydrocolloid acne pimple patch for covering zits and blemishes spot stickers for face and skin (36 count) | Acne Patches |
# | hydrating moisturizing lip glow oil nourishing glossy transparent plumping oil non-sticky tinted toot lip balm for lip care | Lip Oil |
# | cerave foaming facial cleanser  daily face wash for oily skin with hyaluronic acid ceramides and niacinamide fragrance free  16 fluid ounce | Face Wash |
# | vitamin c face serum - dark spot remover facial serum vit c serum with hyaluronic acid ferulic acid & vit e - anti aging and skin brightening serum pure vitamin c serum skin care | Face Serum |
# | cerave retinol serum for post-acne marks and skin texture  pore refining resurfacing brightening facial serum with retinol and niacinamide  fragrance free paraben free & non-comedogenic 1 oz | Face Serum |
# | cerave moisturizing cream  body and face moisturizer for dry skin  body cream with hyaluronic acid and ceramides  daily moisturizer  oil-free  fragrance free  non-comedogenic  19 ounce | Body Cream |
#
# Content of response_df:
#                                        product_title    product_type
# 0   tree hut vitamin c shea sugar scrub 18 oz ult...     Body Scrub
# 1   ice roller for face and eye ice face rollerfa...   Beauty Tools
# 2   mario badescu facial spray with aloe herbs an...      Face Mist
# 3   cerave skin renewing night cream  niacinamide...     Face Cream
# 4   hero cosmetics mighty patch™ original patch -...   Acne Patches
# 5   hydrating moisturizing lip glow oil nourishin...        Lip Oil
# 6   cerave foaming facial cleanser  daily face wa...      Face Wash
# 7   vitamin c face serum - dark spot remover faci...     Face Serum
# 8   cerave retinol serum for post-acne marks and ...     Face Serum
# 9   cerave moisturizing cream  body and face mois...     Body Cream
#
# Response for Chunk 3:
# ```
#                                                product_title  product_type
# 0      vitamin c face mask with kaolin clay and turmeric ...  Face Mask
# 1  the ordinary face serum set! caffeine solution 5%+egcg! ...  Skincare Set
# 2  cerave am facial moisturizing lotion with spf 30  oil-fre...  Face Moisturizer
# 3  paula&#x27;s choice skin perfecting 2% bha liquid salicylic...  Face Exfoliator
# 4  la roche posay tolerianeface moisturizerfacedouble repai...  Face Moisturizer
# 5  baimei jade roller & gua sha face roller facial beauty ...  Beauty Tools
# 6  cerave hydrating toner for face non-alcoholic with hyal...  Face Toner
# 7  clean skin club clean towels xl™ 100% usda biobased fa...  Face Wipes
# 8  bio-oil skincare body oil vitamin e serum for scars & s...  Body Oil
# 9  wsyub makeup headbands 1pcs black spa headband fluffy bo...  Head Band
# ```
#
# Response for Chunk 4:
# | product_title | product_type |
# |---|---|
# | glow recipe fruit babies skincare kit - gift set with ceramide facial cleanser bha toner vitamin c eye cream hyaluronic acid cream & niacinamide dew drops (5 count) | Skincare Set |
# | image skincare vital c hydrating repair crème face night cream with hyaluronic acid | Anti-aging Cream |
# | laneige lip sleeping mask: nourish hydrate vitamin c murumuru & shea butter antioxidants flaky dry lips | Lip Mask |
# | aquaphor healing ointment - dry skin moisturizer - hands heels elbows lips - 7 oz. tube | Body Cream |
# | kahi wrinkle bounce multi balm facial moisturizer  all-in-one hydrating lip balm eye cream neck cream make up base & face mist moisture balm stick  daily face moisturizer stick (0.32 fl oz) | Face Moisturizer |
# | sol de janeiro brazilian bum bum cream 75ml | Body Cream |
# | bubble skincare level up balancing face moisturizer - hydrating gel moisturizer formulated with zinc pca + niacinamide for improved texture & radiance - skin care for oily or combination skin (50ml) | Face Moisturizer |
# | the ordinary facial treatment: hyaluronic acid with 2% + b5 (30ml) and the ordinary niacinamide 10% + zinc 1% (30ml) bundle face care set | Face Serum |
# | neutrogena makeup remover wipes ultra-soft cleansing facial towelettes for waterproof makeup alcohol-free plant-based twin pack 25 count (pack of 2) | Makeup Remover |
# | e.l.f. skin hydrated ever after skincare mini kit cleanser makeup remover moisturiser & eye cream for hydrating skin airplane-friendly sizes | Skincare Set |
#
# Content of response_df:
#                                        product_title        product_type
# 0   glow recipe fruit babies skincare kit - gift ...       Skincare Set
# 1   image skincare vital c hydrating repair crème...   Anti-aging Cream
# 2   laneige lip sleeping mask: nourish hydrate vi...           Lip Mask
# 3   aquaphor healing ointment - dry skin moisturi...         Body Cream
# 4   kahi wrinkle bounce multi balm facial moistur...   Face Moisturizer
# 5       sol de janeiro brazilian bum bum cream 75ml          Body Cream
# 6   bubble skincare level up balancing face moist...   Face Moisturizer
# 7   the ordinary facial treatment: hyaluronic aci...         Face Serum
# 8   neutrogena makeup remover wipes ultra-soft cl...     Makeup Remover
# 9   e.l.f. skin hydrated ever after skincare mini...       Skincare Set
#
# Response for Chunk 5:
# ```
#                         product_title product_type
# 0  neutrogena triple age repair anti-aging daily fa...  Anti-aging Cream
# 1  breylee rose eye mask– 60 pcs - eye treatment m...  Eye Mask
# 2  tula skin care cult classic purifying face cle...  Face Cleanser
# 3  skinmedica ha5 rejuvenating hydrator hyaluronic...  Face Serum
# 4  e.l.f. skin holy hydration! face cream moist...  Face Cream
# 5  neutrogena ultra sheer moisturizing face serum...  Face Serum
# 6  the ordinary the daily set (3 pcs: squalane cl...  Skincare Set
# 7  e.l.f. skin hit kit infused with hemp seed oi...  Skincare Set
# 8  cerave anti aging retinol serum  cream serum ...  Face Serum
# 9  youth to the people air-whip moisture face cr...  Face Cream
# ```
#
# Response for Chunk 6:
# | product_title | product_type |
# |---|---|
# | cerave daily moisturizing lotion for dry skin  body lotion & face moisturizer with hyaluronic acid and ceramides  daily moisturizer  fragrance free  oil-free  12 ounce | Body Lotion |
# | simplyvital face moisturizer collagen cream - anti aging neck and décolleté - made in usa day & night face cream - moisturizing lifting & recovery – 1.7oz | Anti-aging Cream |
# | cerave pm facial moisturizing lotion  night cream with hyaluronic acid and niacinamide  ultra-lightweight oil-free moisturizer for face  3 ounce | Face Moisturizer |
# | first aid beauty kp bump eraser body scrub exfoliant for keratosis pilaris with 10% aha 2 oz. | Body Scrub |
# | numbuzin no.3 super glowing essence toner  fermented ingredients niacinamide galactomyces glowy skin radiance  korean skin care for face (6.76 fl oz) | Face Toner |
# | la roche posay effaclaroily skingelpump bottlefacepurifyingfoaming gel | Face Cleanser |
# | seoulceuticals korean skin care 20% vitamin c hyaluronic acid serum + ce ferulic acid - potent anti aging anti wrinkle korean beauty 1oz | Anti-aging Serum |
# | bareminerals butter drench restorative rich face cream hydrating face lotion helps skin retain moisture soothes dry skin non-comedogenic vegan | Face Moisturizer |
# | cerave 100% mineral sunscreen spf 50  face sunscreen with zinc oxide & titanium dioxide  hyaluronic acid + niacinamide + ceramides  oil free sunscreen for face  travel size sunscreen 2.5 oz | Face Sunscreen |
# | cosrx all about snail korean skincare  tsa approved travel size gift set with face gel cleanser essence cream & eye-cream repairing recovering rejuvenating kit with snail mucin korean skincare | Skincare Set |
#
# Content of response_df:
#                                        product_title        product_type
# 0   cerave daily moisturizing lotion for dry skin...        Body Lotion
# 1   simplyvital face moisturizer collagen cream -...   Anti-aging Cream
# 2   cerave pm facial moisturizing lotion  night c...   Face Moisturizer
# 3   first aid beauty kp bump eraser body scrub ex...         Body Scrub
# 4   numbuzin no.3 super glowing essence toner  fe...         Face Toner
# 5   la roche posay effaclaroily skingelpump bottl...      Face Cleanser
# 6   seoulceuticals korean skin care 20% vitamin c...   Anti-aging Serum
# 7   bareminerals butter drench restorative rich f...   Face Moisturizer
# 8   cerave 100% mineral sunscreen spf 50  face su...     Face Sunscreen
# 9   cosrx all about snail korean skincare  tsa ap...       Skincare Set
#
# Response for Chunk 7:
# | product_title | product_type |
# |---|---|
# | vibriance super c serum for mature skin made in usa all-in-one formula hydrates firms lifts smooths targets age spots wrinkles vitamin c serum; 1 fl oz | Anti-aging Serum |
# | valitic kojic acid dark spot remover soap bars with vitamin c retinol collagen turmeric - original japanese complex infused with hyaluronic acid vitamin e shea butter castile olive oil (3 pack) | Body Soap |
# | cosrx snail mucin 92% repair cream daily face gel moisturizer for dry skin acne-prone sensitive skin not tested on animals no parabens korean skincare (3.52 fl oz (pack of 1)) | Face Moisturizer |
# | cerave sa cleanser  salicylic acid cleanser with hyaluronic acid niacinamide & ceramides bha exfoliant for face  fragrance free non-comedogenic  8 ounce | Face Cleanser |
# | weleda skin food original ultra-rich body cream 2.5 fluid ounce plant rich hydrating moisturizer with pansy chamomile and calendula | Body Cream |
# | tula daily spf 30 sunscreen gel - broad spectrum non-greasy reef-safe with blue light & pollution protection | Sunscreen Cream |
# | sunday riley c.e.o. glow vitamin c & turmeric face oil | Face Oil |
# | tatcha the water cream  cream moisturizer for face optimal hydration for pure poreless skin | Face Moisturizer |
# | tiege hanley mens skin care set essential skin care routine for men (system level 1) - face wash kit for fines lines & wrinkles - men&#x27;s skincare set includes face wash facial scrub & moisturizer | Skincare Set |
# | serious skincare insta-tox instant wrinkle smoothing serum - improves appearance of fine lines & wrinkles -temporarily tightens skin - instant line filler - two .75 oz. tubes (2pack) | Anti-aging Serum |
#
# Content of response_df:
#                                        product_title        product_type
# 0   vibriance super c serum for mature skin made ...   Anti-aging Serum
# 1   valitic kojic acid dark spot remover soap bar...          Body Soap
# 2   cosrx snail mucin 92% repair cream daily face...   Face Moisturizer
# 3   cerave sa cleanser  salicylic acid cleanser w...      Face Cleanser
# 4   weleda skin food original ultra-rich body cre...         Body Cream
# 5   tula daily spf 30 sunscreen gel - broad spect...    Sunscreen Cream
# 6   sunday riley c.e.o. glow vitamin c & turmeric...           Face Oil
# 7   tatcha the water cream  cream moisturizer for...   Face Moisturizer
# 8   tiege hanley mens skin care set essential ski...       Skincare Set
# 9   serious skincare insta-tox instant wrinkle sm...   Anti-aging Serum
#
# Response for Chunk 8:
# | product_title | product_type |
# | ----------- | ----------- |
# | truskin vitamin c face serum – anti aging facial serum with vitamin c hyaluronic acid vitamin e & more – brightening serum for dark spots even skin tone eye area fine lines & wrinkles 1 fl oz | Face Serum |
# | cosrx ultimate nourishing rice overnight spa mask 60ml / 2.02 fl.oz  rice extract 68% and niacinamide 2%  korean skin care animal testing free paraben free | Face Mask |
# | pacifica beauty glow baby booster serum for face vitamin c and glycolic acid brightens and supports for all skin types fragrance free clean skin care vegan & cruelty free  1 fl oz | Face Serum |
# | good molecules niacinamide serum - 10% niacinamide balancing b3 facial serum for acne tone texture - brightening and hydrating skincare for face | Face Serum |
# | mario badescu facial spray with aloe cucumber and green tea for all skin types face mist that hydrates & invigorates | Face Mist |
# | cerave hydrating facial cleanser  moisturizing non-foaming face wash with hyaluronic acid ceramides and glycerin  fragrance free paraben free  16 fluid ounce | Face Cleanser |
# | loreal paris collagen daily face moisturizer reduce wrinkles face cream 3.4 oz | Face Moisturizer |
# | no7 future renew damage reversal skincare set - anti aging face serum (.33 fl oz) day cream with spf 25 (1.69 fl oz) & night cream (1.69 fl oz) - reverses visible signs of aging - 3-piece set | Skincare Set |
# | burt&#x27;s bees renewal firming face cream anti-aging retinol alternative moisturizing natural origin skin care 1.8 ounce (packaging may vary) | Face Cream |
# | dots for spots pimple patches for face - pack of 24 hydrocolloid acne patch - invisible zit stickers treatment for face and body - mighty fast-acting vegan & cruelty free korean skin care | Acne Patches |
#
# Content of response_df:
#                                        product_title        product_type
# 0   truskin vitamin c face serum – anti aging fac...         Face Serum
# 1   cosrx ultimate nourishing rice overnight spa ...          Face Mask
# 2   pacifica beauty glow baby booster serum for f...         Face Serum
# 3   good molecules niacinamide serum - 10% niacin...         Face Serum
# 4   mario badescu facial spray with aloe cucumber...          Face Mist
# 5   cerave hydrating facial cleanser  moisturizin...      Face Cleanser
# 6   loreal paris collagen daily face moisturizer ...   Face Moisturizer
# 7   no7 future renew damage reversal skincare set...       Skincare Set
# 8   burt&#x27;s bees renewal firming face cream a...         Face Cream
# 9   dots for spots pimple patches for face - pack...       Acne Patches
#
# Response for Chunk 9:
# ```
#                                                   product_title                                           product_type
# 0   ashlyn 3 pcs clay mask set green tea clay facial mask rose face masks skincare dead sea bubble deep cleanse mask organic facial masks for women face mask skin care set gifts for girls teens                        Face Mask
# 1   cerave hydrating mineral sunscreen with sheer tint  tinted mineral sunscreen with zinc oxide & titanium dioxide  blends seamlessly for healthy glow  tinted moisturizer with spf 30  1.7 fluid ounce             Sunscreen Cream
# 2   la roche-posay toleriane hydrating gentle face cleanser daily facial cleanser with niacinamide and ceramides for sensitive skin moisturizing face wash for normal to dry skin fragrance free                  Face Cleanser
# 3   anua heartleaf 77 soothing toner i ph 5.5 trouble care calming skin refreshing hydrating purifying cruelty free vegan(250ml / 8.45 fl.oz.)                                                        Face Toner
# 4   ouai body cream st. barts - hydrating whipped body cream with cupuaçu butter coconut oil and squalane - softens skin and delivers healthy-looking glow - sulfate-free skin care - 7.5 oz                     Body Cream
# 5   drunk elephant the littles 6.0 skin care set. beste no.9 virgin marula oil t.l.c. framboos serum protini cream c-firma fresh serum umbra sheer sunscreen                                         Skincare Set
# 6   rael pimple patches miracle invisible spot cover - hydrocolloid acne patch for face blemishes zits absorbing patch breakouts spot treatment for skin care facial sticker 2 sizes (96 count)                    Acne Patches
# 7   anai rui turmeric vitamin c clay mask -rose facial mask –avocado green tea mud maskfacial mask skincare for deep cleansingpurify pores spa mask setfacial mask set gifts set 2.5 oz each                  Face Mask
# 8   cosrx low ph good morning gel cleanser daily mild face cleanser for sensitive skin with bha & tea-tree oil ph balancing korean skincare (5.07fl.oz/150ml)                                         Face Cleanser
# 9   anua heartleaf quercetinol pore deep cleansing foam 5.07 fl oz (150 ml)                                             Face Foam
# ```
#
# Response for Chunk 10:
# | product_title | product_type |
# |---|---|
# | neutrogena hydro boost hyaluronic acid facial moisturizer with broad spectrum spf 50 sunscreen daily water gel face moisturizer to hydrate & soothe dry skin fragrance-free 1.7 fl. oz | Face Moisturizer |
# | gifts for womenanti aging skin care routine kitreduce wrinkles & hydrate skinfacial cleansertonercreamserumeye cream skincare gift setwife mom womens gifts for christmas stocking stuffers | Skincare Set |
# | sol de janeiro jet set | Body Cream |
# | tree of life facial serum for face brightening firming hydrating dry skin dermatologist tested - trio power set | Face Serum |
# | auuruza ice face roller and gua sha set ice roller for face & eye puffiness relief beauty facial rollers mold icing massage skin care tools for brighten lubricate shrink pores remove fine lines | Beauty Tools |
# | face moisturizer retinol cream - men and women anti-aging day & night neck décolleté with retinol collagen hyaluronic acid hydrating wrinkle repair safe for all skin types | Face Moisturizer |
# | under eye patches (30 pairs) 24k gold under eye mask for puffy eyes dark circlesbags and wrinkles with collagenrelieves pressure and reduces wrinklesrevitalises and refreshes your skin | Eye Patches |
# | new york biology dead sea mud mask for face and body - spa quality pore reducer for acne blackheads & oily skin natural skincare for women men - tightens skin for a healthier complexion - 8.8 oz | Face Mask |
# | freeman exotic facial mask blends kit peel-off & jelly masks cleansing pore-clearing & hydrating facial masks for all skin types includes silicone mask brush vegan & cruelty-free 4 piece set | Face Mask |
# | medix 5.5 retinol body lotion firming moisturizer  crepey skin care treatment  retinol body cream  retinol cream targets look of crepe skin wrinkles sagging skin & sun damaged skin 15 fl oz | Body Lotion |
#
# Content of response_df:
#                                        product_title        product_type
# 0   neutrogena hydro boost hyaluronic acid facial...   Face Moisturizer
# 1   gifts for womenanti aging skin care routine k...       Skincare Set
# 2                            sol de janeiro jet set          Body Cream
# 3   tree of life facial serum for face brightenin...         Face Serum
# 4   auuruza ice face roller and gua sha set ice r...       Beauty Tools
# 5   face moisturizer retinol cream - men and wome...   Face Moisturizer
# 6   under eye patches (30 pairs) 24k gold under e...        Eye Patches
# 7   new york biology dead sea mud mask for face a...          Face Mask
# 8   freeman exotic facial mask blends kit peel-of...          Face Mask
# 9   medix 5.5 retinol body lotion firming moistur...        Body Lotion
#
# Response for Chunk 11:
# ```
#                                                product_title  product_type
# 0   neutrogena hydro boost eye cream under-eye mo...  Eye Cream
# 1  jan marini skin research bioglycolic face cleans...  Face Cleanser
# 2                      peach & lily glass skin discovery kit  Skincare Set
# 3            panoxyl acne foaming wash benzoyl peroxide 1...  Acne Treatment
# 4   roc retinol correxion anti-aging wrinkle night...  Anti-aging Serum
# 5        bubble skincare deep dive aha + pha exfoliati...  Exfoliating Mask
# 6        hyaluronic acid serum for face (2 oz) - ser...  Face Serum
# 7  men&#x27;s face cream moisturizer - anti-aging crea...  Face Cream
# 8  coslus facial cleansing brush face scrubber: 7in...  Beauty Tools
# 9  artnaturals anti-aging-set with vitamin-c retinol...  Anti-aging Serum
# ```
#
# Response for Chunk 12:
# ```
#                                            product_title             product_type
# 0    cosrx alcohol-free cica toner 150ml / 5.07 fl.oz  ...               Face Toner
# 1    20pcs moisturizing restores moisture lip mask for ...            Lip Mask
# 2  loreal paris revitalift triple power anti-aging fac...          Anti-aging Cream
# 3  olay regenerist retinol 24 max moisturizer retinol ...          Face Moisturizer
# 4  teen skin 3-step skin care kit  daily boys & girls...           Skincare Set
# 5  9-in-1 face scrubber face cleaning brushes super ...          Face Scrub
# 6  fivewan 24k gold under eye patches - 60 pcs eye mas...          Eye Patches
# 7  cosrx snail mucin sheet mask 10 ea snail essence ...           Sheet Mask
# 8  newgo cold eye mask cooling eye mask eye ice pack ...           Eye Mask
# 9  murad clear skin supplement - supplements for acn...           Acne Treatment
# ```
#
# Response for Chunk 13:
# | product_title | product_type |
# |---|---|
# | the ordinary face serum set! ascorbic acid 8%+alpha arbutin 2%! hyaluronic acid 2%+b5! glycolic acid 7% toning solution! help fight visible blemishes and improved skin radiance! | Face Serum |
# | pacifica beauty  glow baby vitamin c trial + value kit  3-piece skin care gift set  travel friendly  brightening face serum face wash/cleanser under eye patches  glycolic acid aha  vegan | Skin Care Set |
# | loreal revitalift anti-wrinkle + firming eye cream 1.7 oz | Eye Cream |
# | cerave acne foaming cream cleanser  acne treatment face wash with 4% benzoyl peroxide hyaluronic acid and niacinamide  cream to foam formula  fragrance free & non comedogenic  5 oz | Acne Treatment |
# | skin daily skincare set gentle skin cleaning & care teenage girls and women gift set includes cleanser serum essence eye cream (4pcs) | Skin Care Set |
# | skin care set japan sakura women beauty gift sets skin care kit with cleanser toner serum eye cream face cream travel kit for women teen girls mom daughter birthday tsa-friendly sizes 5pcs | Skin Care Set |
# | viking revolution mens facial skin care kit - includes rejuvenating face moisturizer (5oz) microdermabrasion facial scrub (5oz) foaming cleanser (5oz) eye cream (1oz) | Skincare Set |
# | iunik centella 70% calming gel cream vegan non-sticky moisturizing blemish care w/centella asiatica tea tree 10% soothes acne rosacea oily & sensitive skin korean skincare | Face Moisturizer |
# | 4 pcs clay facial mask set - turmeric vitamin c green tea dead sea mud and rose clay for deep cleansing moisturizing and refining pores - 240g | Face Mask |
# | avocado skincare set 6-in-1 skincare gift set with facial cleanser face serum face cream eye cream toner & lip balm anti-aging skin care kit for women birthday gifts set for teen girls | Skin Care Set |
#
# Content of response_df:
#                                        product_title        product_type
# 0   the ordinary face serum set! ascorbic acid 8%...         Face Serum
# 1   pacifica beauty  glow baby vitamin c trial + ...      Skin Care Set
# 2   loreal revitalift anti-wrinkle + firming eye ...          Eye Cream
# 3   cerave acne foaming cream cleanser  acne trea...     Acne Treatment
# 4   skin daily skincare set gentle skin cleaning ...      Skin Care Set
# 5   skin care set japan sakura women beauty gift ...      Skin Care Set
# 6   viking revolution mens facial skin care kit -...       Skincare Set
# 7   iunik centella 70% calming gel cream vegan no...   Face Moisturizer
# 8   4 pcs clay facial mask set - turmeric vitamin...          Face Mask
# 9   avocado skincare set 6-in-1 skincare gift set...      Skin Care Set
#
# Response for Chunk 14:
# | product_title | product_type |
# |---|---|
# | hero cosmetics rescue balm & red correct post-blemish recovery cream - nourishing calming dermatologist tested vegan (0.5 fl oz) | Face Cream |
# | maree facial masks with marine collagen & hyaluronic acid - sheet moisturizing masks for face with green & red algae extract for all skin types - hydrating skin care mask with pearl extract - 6 pack | Face Mask |
# | neutrogena skin perfecting daily liquid facial exfoliant with 9% aha/pha blend for normal & combination skin smoothing & brightening leave-on exfoliator oil- & fragrance-free 4 fl. oz | Face Exfoliator |
# | exposed skin care clearing tonic facial toner with 1% salicylic acid and witch hazel for acne treatment – pore minimizing toner to prevent breakouts reduce redness and balance skin – step 2 (4 fl oz) | Face Toner |
# | truskin vitamin c super serum with niacinamide retinol hyaluronic & salicylic acid (bha) - all-in-one anti aging facial serum for brightening firming dark spots discoloration - 1 fl oz | Face Serum |
# | vital proteins collagen peptides powder promotes hair nail skin bone and joint health zero sugar unflavored 9.33 oz | Collagen Powder |
# | pyunkang yul [pky] calming moisture barrier cream instantly soothes sensitive skin hyaluronic acid & ceramide for hydration vegan korean skincare (1.69 fl. oz 50ml) | Face Cream |
# | tatcha the dewy skin cream: rich cream to hydrate | Face Cream |
# | ice roller for face and eye puffiness relief skincare tools cold roller cryotherapy face tools for skincare for women face depuffer (pink) | Beauty Tools |
# | jlo beauty that jlo glow serum  skin care that tightens brightens and hydrates made with niacinamide and squalane | Face Serum |
#
# Content of response_df:
#                                        product_title       product_type
# 0   hero cosmetics rescue balm & red correct post...        Face Cream
# 1   maree facial masks with marine collagen & hya...         Face Mask
# 2   neutrogena skin perfecting daily liquid facia...   Face Exfoliator
# 3   exposed skin care clearing tonic facial toner...        Face Toner
# 4   truskin vitamin c super serum with niacinamid...        Face Serum
# 5   vital proteins collagen peptides powder promo...   Collagen Powder
# 6   pyunkang yul [pky] calming moisture barrier c...        Face Cream
# 7   tatcha the dewy skin cream: rich cream to hyd...        Face Cream
# 8   ice roller for face and eye puffiness relief ...      Beauty Tools
# 9   jlo beauty that jlo glow serum  skin care tha...        Face Serum
#
# Response for Chunk 15:
# | product_title | product_type |
# |---|---|
# | for face blackhead remover with green tea extract deep pore cleansing moisturizing skin brightening for all skin types of men and women (pack of 2) | Face Cleanser |
# | facial cleansing brush  face scrubber exfoliator skin care beauty products powered electric wash exfoliating skincare women spin cleanser tools cleaning scrub washer self care (opal) | Face Exfoliator |
# | eminence bamboo firming fluid 1.2 ounce | Face Serum |
# | eminence organic skincare stone crop hydrating mist 4.2 ounce | Face Mist |
# | 3set forge- wrinkle defense tallow balmskin care for men (tallow cream + tallow night serum + tallow face wash) tallow balm face moisturizermens facial care kitanti-wrinkle night serum anti aging | Anti-aging Serum |
# | glossmetics essential bundle skin care set for teen girls - skin care gift set for women facial skin care sets & kits for all skin type - combination skin care set skincare kits for teens | Skincare Set |
# | retinol cream for face day and night anti aging face cream anti wrinkle collagen moisturizer for face with niacinamide and peptides for women and men 1.7 fl oz | Anti-aging Cream |
# | cosrx advanced snail hydrogel eye patch (60pc) gel serum mask puffy undereye treament fine lines refresh hydrate paraben free korean skincare | Eye Patches |
# | facetory best of seven facial masks collection - hydrate radiance boost soothe revitalize nourish purify skin - for all skin types variety pack of 7 sheet masks | Sheet Mask |
# | turmeric skincare set - turmeric skin care products brightening & acne - turmeric skin care kit turmeric skin care set - turmeric cleanser body scrub face cream & facial serum | Skincare Set |
#
# Content of response_df:
#                                        product_title        product_type
# 0   for face blackhead remover with green tea ext...      Face Cleanser
# 1   facial cleansing brush  face scrubber exfolia...    Face Exfoliator
# 2           eminence bamboo firming fluid 1.2 ounce          Face Serum
# 3   eminence organic skincare stone crop hydratin...          Face Mist
# 4   3set forge- wrinkle defense tallow balmskin c...   Anti-aging Serum
# 5   glossmetics essential bundle skin care set fo...       Skincare Set
# 6   retinol cream for face day and night anti agi...   Anti-aging Cream
# 7   cosrx advanced snail hydrogel eye patch (60pc...        Eye Patches
# 8   facetory best of seven facial masks collectio...         Sheet Mask
# 9   turmeric skincare set - turmeric skin care pr...       Skincare Set
#
# Response for Chunk 16:
# | product_title | product_type |
# |---|---|
# | bliss mighty marshmallow bright & radiant whipped mask - brightening & hydrating face mask - 1.7 oz - luminious skin - clean - vegan & cruelty-free - all skin types | Face Mask |
# | rice toner for face korean skin care (5.07 fl oz) from korean toner 77.78% rice extract from korea glow essence with niacinamide hydrating for all skin vegan alcohol & fragrance free | Face Toner |
# | exposed skin care acne facial cleanser - gentle face wash with salicylic acid for acne prone skin - pore clarifying acne treatment for all ages skin types | Face Cleanser |
# | origins plantscription multi-powered youth serum women serum 1 oz | Face Serum |
# | watermelon niacinamide face serum face serum with citrullus vulgaris(watermelon) fruit extract sodium hyaluronate glycerin serum for skin care moisturize (1pcs) | Face Serum |
# | retinol cream for face anti wrinkle face cream with collagen for women & men anti aging cream - vitamin e & hyaluronic acid for skin care day & night cream revitalizing face moisturizer - 1.7 oz | Anti-aging Cream |
# | w7 self-care skincare set - 5 step daily routine - moisturizer serum toner cleanser & lip mask - full size skin care kit for natural beautiful skin | Skincare Set |
# | skin care set - women gift sets - sakura skin care sets & kits - gift set with cleansertonerserumeye creamessence serum - beauty products for women (setc) | Skincare Set |
# | face serum set – retinol serum vitamin c & hyaluronic acid for face – anti aging serum skin care set for women – serum for firm wrinkle smoothing dark spot corrector brighten dullness | Face Serum |
# | eminence organic skincare firm skin acai cleanser with hyaluronic acid 8.4 ounce | Face Cleanser |
#
# Content of response_df:
#                                        product_title        product_type
# 0   bliss mighty marshmallow bright & radiant whi...          Face Mask
# 1   rice toner for face korean skin care (5.07 fl...         Face Toner
# 2   exposed skin care acne facial cleanser - gent...      Face Cleanser
# 3   origins plantscription multi-powered youth se...         Face Serum
# 4   watermelon niacinamide face serum face serum ...         Face Serum
# 5   retinol cream for face anti wrinkle face crea...   Anti-aging Cream
# 6   w7 self-care skincare set - 5 step daily rout...       Skincare Set
# 7   skin care set - women gift sets - sakura skin...       Skincare Set
# 8   face serum set – retinol serum vitamin c & hy...         Face Serum
# 9   eminence organic skincare firm skin acai clea...      Face Cleanser
#
# Response for Chunk 17:
# ```
#                                                product_title  product_type
# 0  instanatural vitamin c cleanser face wash brightens an...  Face Wash
# 1  blue red light theràpy màsk for face 7 colors led fa...  Anti-aging Mask
# 2  drunk elephant hydra and the bright - includes c-firm...  Face Serum
# 3  evereden kids happy face duo (cool peach) - multi-vi...  Kids Care
# 4  dermalogy by neogenlab neogen real fresh foam cleanse...  Face Foam
# 5  anti-aging & wrinkle moisturizer face cream for wome...  Anti-aging Cream
# 6  alpha skin care enhanced wrinkle repair cream anti-agi...  Anti-aging Cream
# 7  pearlessence rosehip balancing facial oil + rosehip f...  Face Oil
# 8  revision skincare nectifirm advanced neck firming cr...  Neck Cream
# 9  no7 menopause skincare nourishing overnight cream - h...  Face Cream
# ```
#
# Response for Chunk 18:
# | product_title | product_type |
# |---|---|
# | paula's choice boost 10% azelaic acid booster cream gel licorice extract & salicylic acid oil-free skin brightening serum 1 ounce | Face Serum |
# | first aid beauty facial radiance pads – daily exfoliating pads with aha that help tone & brighten skin – compostable for daily use – 28 pads | Face Exfoliator |
# | new lift & firm anti aging face & neck cream - made in europe - firming & lifting anti aging moisturizer with hyaluronic acid elastin vitamin c+e | Anti-aging Cream |
# | i dew care skincare set - vitamin to glow pack  with niacinamide grapefruit extract vitamin c trio set spa day gift set travel size glass skin korean skincare | Skincare Set |
# | disposable face towel 200 count soft cotton face clean towels dry wipes facial cloths towelettes for washing and drying lint free facial tissue for skincare makeup remover and cleansing | Beauty Tools |
# | skincare gifts for teenage girls skincare kits - 7pcs skin care sets & kits - vitamin c skin care sets - pamper sets for women gifts includes cleanser- serum-eye serum-toner-cream-face mask skincare | Skincare Set |
# | evereden kids daily 1-2-3 routine bundle: clean & vegan skin care set - hydrating & nourishing tween skincare set with multi-vitamin face wash face cream lotion & spf 30 mineral sunscreen (melon) | Kids Care |
# | skincare gift set for teenage girlsvitamin c skin care set - 5 piece gentle skin cleaning & care travel size kit with cleanser toner face serumeye creamface cream brighten face skin care kit | Skincare Set |
# | skin care set vitamin c women beauty gift sets skin care kit with cleanser toner serum eye cream face cream travel kit for women teen girls mom daughter birthday tsa-friendly sizes 5pcs… | Skincare Set |
# | konssy 6 pack face cloths soft wash cloth for washing face cotton face towels for sensitive skin women facial makeup remover reusable absorbent washcloths （11 x 11 inch） | Beauty Tools |
#
# Content of response_df:
#                                        product_title        product_type
# 0   paula's choice boost 10% azelaic acid booster...         Face Serum
# 1   first aid beauty facial radiance pads – daily...    Face Exfoliator
# 2   new lift & firm anti aging face & neck cream ...   Anti-aging Cream
# 3   i dew care skincare set - vitamin to glow pac...       Skincare Set
# 4   disposable face towel 200 count soft cotton f...       Beauty Tools
# 5   skincare gifts for teenage girls skincare kit...       Skincare Set
# 6   evereden kids daily 1-2-3 routine bundle: cle...          Kids Care
# 7   skincare gift set for teenage girlsvitamin c ...       Skincare Set
# 8   skin care set vitamin c women beauty gift set...       Skincare Set
# 9   konssy 6 pack face cloths soft wash cloth for...       Beauty Tools
#
# Response for Chunk 19:
# | product_title | product_type |
# |---|---|
# | caudalie vinoperfect brightening dark spot serum - 62x more effective than vitamin c | Face Serum |
# | farmacy honey halo ceramide face moisturizer cream - hydrating facial lotion for dry skin (0.8 ounce) | Face Moisturizer |
# | éminence calm skin chamomile cleanser by eminence for unisex - 8.4 oz cleanser | Face Cleanser |
# | paula&#x27;s choice clear extra strength acne kit 2% salicylic acid & 5% benzoyl peroxide for severe acne redness relief packaging may vary | Acne Treatment |
# | cnp propolis energy active serum - revitalizing face repair ampule for sensitive skin intense hydration soothing non-sticky radiance korean skin care hyaluronic acid (small (0.5 fl.oz)) | Face Serum |
# | green tea purifying clay face mask face moisturizes oil control blackhead remover deep clean pore purifying clay stick deep cleansing mask for all skin men women (green tea) | Face Mask |
# | sakura travel skincare set for teenage girls - face routine set for women4 piece gentle skin cleaning & care travel size kit with cleanser toner sunscreen and face cream | Skincare Set |
# | vitamin c skincare set 5-in-1 skincare gift set with cleanser toner face serum face cream and eye cream skin care products for teen girls long-lasting moisturizing skincare set for women men | Skincare Set |
# | w7 skin refresh essential full size skin care set - 4 step daily routine - moisturizer cleansing gel toner and serum for natural beautiful skin | Skincare Set |
# | anti wrinkle matrixyl 3000 hyaluronic acid serum for face  collagen serum  anti-aging & hydrating for deep wrinkle repair  face tightening & firming serum for fine lines & forehead wrinkles | Anti-aging Serum |
#
# Content of response_df:
#                                        product_title        product_type
# 0   caudalie vinoperfect brightening dark spot se...         Face Serum
# 1   farmacy honey halo ceramide face moisturizer ...   Face Moisturizer
# 2   éminence calm skin chamomile cleanser by emin...      Face Cleanser
# 3   paula&#x27;s choice clear extra strength acne...     Acne Treatment
# 4   cnp propolis energy active serum - revitalizi...         Face Serum
# 5   green tea purifying clay face mask face moist...          Face Mask
# 6   sakura travel skincare set for teenage girls ...       Skincare Set
# 7   vitamin c skincare set 5-in-1 skincare gift s...       Skincare Set
# 8   w7 skin refresh essential full size skin care...       Skincare Set
# 9   anti wrinkle matrixyl 3000 hyaluronic acid se...   Anti-aging Serum
#
# Response for Chunk 20:
# | product_title | product_type |
# | ----------- | ----------- |
# | i dew care skincare set - kitten my balance on  with kaolin heartleaf extract foam cleanser wash-off mask serum for blemish skin gift travel size korean skincare tsa friendly sizes | Skincare Set |
# | facial skin care set & spa kit - mothers day gift ideas self-care relaxation gifts skin care collection with essential oils hyaluronic acid vitamin e. (lavender) | Skincare Set |
# | peptide moisturizer cream for face - dry skin sensitive skin skin protection barrier cream for aging skin anti aging hydrating peptide ceramide panthenol (1.69 fl.oz) | Face Moisturizer |
# | 6 piece avocado skincare kit moisturizing skin care set with facial cleanser toner face serum face cream eye cream for hydrating skin anti-aging skin for women teen girls | Skincare Set |
# | ice roller for face massage facial roller for skin tightenreduce puffiness eliminate wrinklesmigraine pain relief face massager women gifts skin care tool | Beauty Tools |
# | sleeping lip mask nourish & hydrate lip mask lip balm lip oil lip skin care hydrating moisturizing lip lines night sleep anti-chapped lip cream (grapefruit) | Lip Mask |
# | etude soonjung 10 free moist emulsion 4.39 fl. oz (130ml) 23ad  hypoallergenic non-irritating hydrating emulsion for skin damage care and relaxation  korean skin care | Face Moisturizer |
# | cosrx master patch intensive  oval-shaped hydrocolloid pimple patch with tea tree oil & salicylic acid  quick & easy blemish zit spot treatment (10 patches (x-large) 10 count) | Acne Patches |
# | bijou bijou cloud serum- natural hyaluronic acid alternative not your ordinary pink serum formulated to be hydrating moisturizing firming vegan jelly like collagen made w/tremella mushroom | Face Serum |
# | mighty patch micropoint from hero cosmetics - post-blemish dark spot patch with 395 micropoints dermatologist tested and non-irritating not tested on animals (8 count) | Acne Patches |
#
# Content of response_df:
#                                        product_title        product_type
# 0   i dew care skincare set - kitten my balance o...       Skincare Set
# 1   facial skin care set & spa kit - mothers day ...       Skincare Set
# 2   peptide moisturizer cream for face - dry skin...   Face Moisturizer
# 3   6 piece avocado skincare kit moisturizing ski...       Skincare Set
# 4   ice roller for face massage facial roller for...       Beauty Tools
# 5   sleeping lip mask nourish & hydrate lip mask ...           Lip Mask
# 6   etude soonjung 10 free moist emulsion 4.39 fl...   Face Moisturizer
# 7   cosrx master patch intensive  oval-shaped hyd...       Acne Patches
# 8   bijou bijou cloud serum- natural hyaluronic a...         Face Serum
# 9   mighty patch micropoint from hero cosmetics -...       Acne Patches
#
# Response for Chunk 21:
# ```
#         product_title                                                        product_type
# 0   truskin tea tree super cleanser – acne face wash with tea tree oil alo...   Face Wash
# 1   green tea skincare set 19-in-1 skincare gift set with natural extracts...   Skincare Set
# 2   bubble skincare come clean detoxifying clay mask - mineral-rich face m...   Face Mask
# 3   forge-wrinkle defense tallow balmskin care for mennatural tallow mo...   Anti-aging Cream
# 4   ice roller for face ice cube facial roller massager (de-puff eye bags...   Beauty Tools
# 5   permotary 30 pcs collagen lip mask crystal lip care gel pads for mois...   Lip Mask
# 6   jelly mask for facials professional natural gel face masks hydrating r...   Face Mask
# 7   panoxyl blemish brightening patches: dermatologist-recommended help ...   Acne Patches
# 8   24k gold eye masks-with collagen under eye patches dark circles under ...   Eye Mask
# 9   sakura face care set for women 17pcs moisturizing skin care set includ...   Skincare Set
# ```
#
# Response for Chunk 22:
# | product_title | product_type |
# | ----------- | ----------- |
# | facial skin care sets sakura skin care set complete skin care gift set with face cream face serum eye mask lip mask 5*face sleeping mask & 5*face mud mask hydrating skincare kit for teen girls | Skincare Set |
# | vitamin c serum with collagen - dermatologist tested korean skin care for dark spots & skin brightening - anti aging & acne facial serum - cruelty free - for all skin types - 1.69oz (2pk) by skin 2.0 | Anti-aging Serum |
# | roselynboutique healing crystal gua sha facial tools - guasha massager tool (pink guasha) | Beauty Tools |
# | laneige water bank blue hyaluronic gel moisturizer: with mint extract hypoallergenic dermatologist-tested | Face Moisturizer |
# | jlo beauty that jlo starter kit  includes serum cleanser and cream gently tightens clears brightens and hydrates for smooth radiant skin | Skincare Set |
# | jlo beauty that hit single gel cream cleanser  sulfate-free antioxidant-rich clears brightens & removes makeup for smooth radiant skin  5 oz | Face Cleanser |
# | gifts for menmens anti aging skin care kitreduce wrinkles & hydrate skin w/facial cleanserscrubcreamserumeye cream unique men gifts stocking stuffers for christmasgift for him boyfriend husband | Skincare Set |
# | mens gifts for menmens skin care kitnourishe & hydrate skin w/face washscrublotioncreamdeodorantmens stocking stuffers for menunique christmas gifts for men him dad husband boyfriend teen boy | Skincare Set |
# | the face lotion for sensitive skin - am + pm confidence boost - ph balanced teen and tween face moisturizer - kid skin care with blue light defense - 1.7 oz | Face Moisturizer |
# | celavi k-beauty skincare essence facial face mask korea skin care moisturizing b set 12 pack | Face Mask |
#
# Content of response_df:
#                                        product_title        product_type
# 0   facial skin care sets sakura skin care set co...       Skincare Set
# 1   vitamin c serum with collagen - dermatologist...   Anti-aging Serum
# 2   roselynboutique healing crystal gua sha facia...       Beauty Tools
# 3   laneige water bank blue hyaluronic gel moistu...   Face Moisturizer
# 4   jlo beauty that jlo starter kit  includes ser...       Skincare Set
# 5   jlo beauty that hit single gel cream cleanser...      Face Cleanser
# 6   gifts for menmens anti aging skin care kitred...       Skincare Set
# 7   mens gifts for menmens skin care kitnourishe ...       Skincare Set
# 8   the face lotion for sensitive skin - am + pm ...   Face Moisturizer
# 9   celavi k-beauty skincare essence facial face ...          Face Mask
#
# Response for Chunk 23:
# | product_title | product_type |
# | ----------- | ----------- |
# |turmeric + 30% vitamin c face glow booster moisturizer & skin repairing cream - with hyaluronic acid organic ingredients – hydrating face moisturizer for dry normal oily skin – anti-aging | Face Moisturizer |
# | glazed for dayz bundle - hydrating skincare routine set for women teen preppy skincare set - includes peptide glazed face serum dewly hydrated moisturizer and lychee berry lip glaze | Skincare Set |
# | timeless skin care squalane oil 100% pure - 1 fl oz - lightweight plant-based dry oil - improves skin elasticity & radiance - regulates oil production - all skin types including acne-prone skin | Face Oil |
# | watermelon niacinamide highlighting serum - illuminating makeup primer & facial serum with hyaluronic acid - moisturizing lightweight & priming for glowing skin care (75ml) | Face Serum |
# | mens skin care set no. 204 daily essential face kit no. 121 facial cleanser no. 123 facial moisturizer no. 127 eye cream no. 128 daily face lotion with spf 50 great gift for men | Skincare Set |
# | pimple patch - hydrocolloid acne patch for face zits - blemish spot skin care treatment - invisible dots waterproof absorbs pus avoids scar reduces pain & redness of acne (36 patches) | Acne Patches |
# | eminence age corrective monoi exfoliating cleanser 8.4oz(250ml) treatment beauty skin | Face Exfoliator |
# | jlo beauty that jlo essentials kit  includes serum cleanser cream and broad spectrum spf gently tightens brightens protects & hydrates skin | Skincare Set |
# | herbivore pink cloud plumping + hydration moisturizing skincare with tremella mushroom plant-based vegan cruelty-free | Face Moisturizer |
# | principal secret advanced – gentle deep 4-in-1 cleanser – 6 ounces | Face Cleanser |
#
# Content of response_df:
#                                        product_title        product_type
# 0  turmeric + 30% vitamin c face glow booster moi...   Face Moisturizer
# 1   glazed for dayz bundle - hydrating skincare r...       Skincare Set
# 2   timeless skin care squalane oil 100% pure - 1...           Face Oil
# 3   watermelon niacinamide highlighting serum - i...         Face Serum
# 4   mens skin care set no. 204 daily essential fa...       Skincare Set
# 5   pimple patch - hydrocolloid acne patch for fa...       Acne Patches
# 6   eminence age corrective monoi exfoliating cle...    Face Exfoliator
# 7   jlo beauty that jlo essentials kit  includes ...       Skincare Set
# 8   herbivore pink cloud plumping + hydration moi...   Face Moisturizer
# 9   principal secret advanced – gentle deep 4-in-...      Face Cleanser
#
# Response for Chunk 24:
# | product_title | product_type |
# |---|---|
# | fruit of the earth vitamin e skin care cream 4 oz (113 g) | Face Moisturizer |
# | organic face moisturizer cream with collagen peptides and hyaluronic acid anti aging moisturizing face lotion for women and men award winning paraben free for anti wrinkle skin with shea and jojoba | Face Moisturizer |
# ...
#
# Content of response_df:
# Empty DataFrame
# Columns: [product_title, product_type]
# Index: []
#
# DataFrame is empty. Skipping.
# Response for Chunk 31:
# ```
#                                                    product_title                                            product_type
# 0  roc multi correxion hyaluronic acid night serum capsules (30 ct) for intense hydration + roc retinol capsules (7 ct) skin care routine anti-aging skin care wrinkle treatment for women and men  Anti-aging Serum
# 1                                       i dew care lip mask - plush party  overnight moisturizing vitamin c sleeping balm with cocoa butter for dry lips 0.42 oz                   Lip Mask
# 2  dr. b dental solutions cleanadent wipes - convenient denture cleaning wipes refreshes gums no artificial colors/flavors - 30 pack                                     Face Wipes
# 3  burt's bees aloe vera face wipes for sensitive skin soothing makeup remover & facial cleansing towelettes 30 ct. (3-pack)                               Face Wipes
# 4        cocojojo coco glucoside surfactant 16 oz - natural foaming cleanser - plant derived - biodegradable - for formulations and diy skin care - for shower gels body soap shampoos face cleansers  Body Soap
# 5        differin acne-prone skin patches for early-stage imperfections formulated with salicylic acid and centella fast triple action power patch for day & night dermatologist tested 36 count  Acne Patches
# 6                                          philosophy purity made simple - moisturizer                                         Face Moisturizer
# 7                                          red led face mask light therapy at home 7-1 colors led facial skin care mask blue red light therapy mask for face                          Anti-aging Mask
# 8  revlon designer series slant tweezer high precision tweezer made with long lasting stainless steel 1 count                                                    Beauty Tools
# ```
#
# Response for Chunk 32:
# | product_title | product_type |
# | ----------- | ----------- |
# | paulas choice--skin perfecting 2% bha liquid salicylic acid exfoliant--facial exfoliant for blackheads enlarged pores wrinkles & fine lines 4 oz bottle | Face Exfoliator |
# | winner disposable face towels  100% usa cotton face towelettes super soft & thick face cloths for sensitive skin makeup remover dry wipes face drying towels for skin care 55 count 1 pack | Makeup Remover |
# | botalinum ampoule - face serum & ampoule with 50% hyaluronic acid  face lifting & brightening serum  hydrating serum for face  firming ampoule korean skin care serum (1.0 fl. oz.) | Face Serum |
# | bentonite clay baby powder pure calcium bentonite clay food grade baby powder for sensitive skin travel size baby powder gentle baby skin care | Body Powder |
# | bluelayer double water cream(1.76 oz) blue capsule cream for hydrating skin nano-hyaluronic acid & blue agave korean skincare | Face Cream |
# | nécessaire the body wash. hinoki. resurfacing cleanse. multi-acids gel cleanser for uneven skin. hypoallergenic. dermatologist-tested. no sls/sles. 8.4 fl oz | Body Wash |
# | dermalogica stabilizing repair cream face moisturizer for sensitive skin with cica - strengthens soothes and repairs skin barrier 1.7 fl oz | Face Moisturizer |
# | ed hardy coconut kisses golden tanning lotion 13.5 oz  best sellers  tanning paradise maui black tanning lotion  coconut oil  age-defying  tattoo protecting formula  ultra hydrating dark tanning lotion 13.5oz | Tanning Lotion |
# | all natural mens anti chafing powder deep mined calcium bentonite clay powder body groin arm pit foot anti chafe powder paraben free talc free food grade organic 8 oz | Anti Chafe |
#
# Content of response_df:
#                                        product_title        product_type
# 0   paulas choice--skin perfecting 2% bha liquid ...    Face Exfoliator
# 1   winner disposable face towels  100% usa cotto...     Makeup Remover
# 2   botalinum ampoule - face serum & ampoule with...         Face Serum
# 3   bentonite clay baby powder pure calcium bento...        Body Powder
# 4   bluelayer double water cream(1.76 oz) blue ca...         Face Cream
# 5   nécessaire the body wash. hinoki. resurfacing...          Body Wash
# 6   dermalogica stabilizing repair cream face moi...   Face Moisturizer
# 7   ed hardy coconut kisses golden tanning lotion...     Tanning Lotion
# 8   all natural mens anti chafing powder deep min...         Anti Chafe
#
# Response for Chunk 33:
# | product_title | product_type |
# | --- | --- |
# | clean skin club clean towels xl™ 100% usda biobased face towel disposable face towelette makeup remover dry wipes ultra soft 50 ct 1 pack | Makeup Remover |
# | valitic kojic acid dark spot remover soap bars with vitamin c retinol collagen turmeric - original japanese complex infused with hyaluronic acid vitamin e shea butter castile olive oil (2 pack) | Acne Treatment |
# | cosrx snail mucin 96% power repairing essence 3.38 fl.oz 100ml hydrating serum for face with snail secretion filtrate for dull skin & fine lines korean skincare | Face Serum |
# | eos shea better body lotion- vanilla cashmere 24-hour moisture skin care lightweight & non-greasy made with natural shea vegan 16 fl oz | Body Lotion |
# | blue lizard sensitive mineral sunscreen with zinc oxide spf 50+ water resistant uva/uvb protection with smart bottle technology - fragrance free 5 oz | Sunscreen Cream |
# | dove body wash with pump deep moisture for dry skin moisturizing skin cleanser with 24hr renewing micromoisture nourishes the driest skin 30.6 oz | Body Wash |
# | eltamd uv clear face sunscreen oil free sunscreen with zinc oxide dermatologist recommended sunscreen 1.7 oz pump | Face Sunscreen |
# | paulas choice--skin perfecting 2% bha liquid salicylic acid exfoliant--facial exfoliant for blackheads enlarged pores wrinkles & fine lines 4 oz bottle | Face Exfoliator |
# | aquaphor lip repair stick lip protectant moisturizing lip balm multipack 2 count (pack of 1) | Lip Balm |
#
# Content of response_df:
#                                        product_title       product_type
# 0   clean skin club clean towels xl™ 100% usda bi...    Makeup Remover
# 1   valitic kojic acid dark spot remover soap bar...    Acne Treatment
# 2   cosrx snail mucin 96% power repairing essence...        Face Serum
# 3   eos shea better body lotion- vanilla cashmere...       Body Lotion
# 4   blue lizard sensitive mineral sunscreen with ...   Sunscreen Cream
# 5   dove body wash with pump deep moisture for dr...         Body Wash
# 6   eltamd uv clear face sunscreen oil free sunsc...    Face Sunscreen
# 7   paulas choice--skin perfecting 2% bha liquid ...   Face Exfoliator
# 8   aquaphor lip repair stick lip protectant mois...          Lip Balm
#
# Response for Chunk 34:
# | product_title | product_type |
# | ----------- | ----------- |
# | skinsmart facial cleanser for acne targets bacteria for active teenage athletes post workout and adult acne 8 oz spray bottle safe for multiple daily uses | Face Cleanser |
# | cerave daily moisturizing lotion for dry skin  body lotion & face moisturizer with hyaluronic acid and ceramides  daily moisturizer  fragrance free  oil-free  19 ounce | Body Lotion |
# | neutrogena ultra sheer dry-touch water resistant and non-greasy sunscreen lotion with broad spectrum spf 70 3 fl oz (pack of 1) | Sunscreen Cream |
# | cerave am facial moisturizing lotion with spf 30  oil-free face moisturizer with spf  formulated with hyaluronic acid niacinamide & ceramides  non-comedogenic  broad spectrum sunscreen  3 ounce | Face Moisturizer |
# | sun bum original spf 50 sunscreen spray vegan and hawaii 104 reef act compliant (octinoxate & oxybenzone free) broad spectrum moisturizing uva/uvb sunscreen with vitamin e  6 oz | Sunscreen Spray |
# | solar buddies refillable roll on sponge applicator for kids adults families travel size holds 100ml travel friendly for sunscreen suncream and lotions (blue) | Skincare Set |
# | softsoap liquid hand soap fresh breeze - 7.5 fl oz (pack of 6) | Hand Soap |
# | differin acne treatment gel 30 day supply retinoid treatment for face with 0.1% adapalene gentle skin care for acne prone sensitive skin 15g tube | Acne Treatment |
# | cerave hydrating mineral sunscreen with sheer tint  tinted mineral sunscreen with zinc oxide & titanium dioxide  blends seamlessly for healthy glow  tinted moisturizer with spf 30  1.7 fluid ounce | Face Sunscreen |
#
# Content of response_df:
#                                        product_title        product_type
# 0   skinsmart facial cleanser for acne targets ba...      Face Cleanser
# 1   cerave daily moisturizing lotion for dry skin...        Body Lotion
# 2   neutrogena ultra sheer dry-touch water resist...    Sunscreen Cream
# 3   cerave am facial moisturizing lotion with spf...   Face Moisturizer
# 4   sun bum original spf 50 sunscreen spray vegan...    Sunscreen Spray
# 5   solar buddies refillable roll on sponge appli...       Skincare Set
# 6   softsoap liquid hand soap fresh breeze - 7.5 ...          Hand Soap
# 7   differin acne treatment gel 30 day supply ret...     Acne Treatment
# 8   cerave hydrating mineral sunscreen with sheer...     Face Sunscreen
#
# Response for Chunk 35:
# | product_title | product_type |
# |---|---|
# | simplyvital face moisturizer collagen cream - anti aging neck and décolleté - made in usa day & night face cream - moisturizing lifting & recovery – 1.7oz | Face Cream |
# | sun bum spf 30 sunscreen lip balm  vegan and cruelty free broad spectrum uva/uvb lip care with aloe and vitamin e for moisturized lips  variety pack 0.15 ounce (pack of 3) | Lip Balm |
# | anua heartleaf 77 soothing toner i ph 5.5 trouble care calming skin refreshing hydrating purifying cruelty free vegan(250ml / 8.45 fl.oz.) | Face Toner |
# | thayers alcohol-free hydrating rose petal witch hazel facial toner with aloe vera formula vegan dermatologist tested and recommended 12 oz | Face Toner |
# | cerave retinol serum for post-acne marks and skin texture  pore refining resurfacing brightening facial serum with retinol and niacinamide  fragrance free paraben free & non-comedogenic 1 oz | Face Serum |
# | cerave eye repair cream  under eye cream for dark circles and puffiness  suitable for delicate skin under eye area  0.5 ounce | Eye Cream |
# | anua heartleaf quercetinol pore deep cleansing foam facial cleanser for double cleansing bha hyaluronic acid glycerin face wash blackhead remover korean skincare (150ml/50 fl.oz.) | Face Foam |
# | vanicream gentle facial cleanser with pump dispenser - 8 fl oz - formulated without common irritants for those with sensitive skin | Face Cleanser |
# | dial antibacterial foaming hand soap refill spring water 52 fl oz | Hand Soap |
#
# Content of response_df:
#                                        product_title     product_type
# 0   simplyvital face moisturizer collagen cream -...      Face Cream
# 1   sun bum spf 30 sunscreen lip balm  vegan and ...        Lip Balm
# 2   anua heartleaf 77 soothing toner i ph 5.5 tro...      Face Toner
# 3   thayers alcohol-free hydrating rose petal wit...      Face Toner
# 4   cerave retinol serum for post-acne marks and ...      Face Serum
# 5   cerave eye repair cream  under eye cream for ...       Eye Cream
# 6   anua heartleaf quercetinol pore deep cleansin...       Face Foam
# 7   vanicream gentle facial cleanser with pump di...   Face Cleanser
# 8   dial antibacterial foaming hand soap refill s...       Hand Soap
#
# Response for Chunk 36:
# | product_title | product_type |
# | ----------- | ----------- |
# | softsoap antibacterial liquid hand soap refill white tea & berry scented hand soap 50 ounce(packaging may vary) | Hand Soap |
# | aquaphor lip repair tubes lip ointment for chapped lips moisturizing lip balm two 0.35 ounce tubes | Lip Balm |
# | eltamd uv daily spf 40 tinted face sunscreen moisturizer lightweight tinted sunscreen for face 1.7 oz pump | Face Sunscreen |
# | l’oréal paris collagen daily face moisturizer reduce wrinkles face cream 1.7 oz | Face Moisturizer |
# | biodance bio-collagen real deep mask hydrating overnight mask pore minimizing elasticity improvement 34g x4ea | Face Mask |
# | cetaphil face & body moisturizer hydrating moisturizing cream for dry to very dry sensitive skin new 20 oz fragrance free non-comedogenic non-greasy (packaging may vary) | Body Moisturizer |
# | sun bum kids spf 50 clear sunscreen face stick  wet or dry application  hawaii 104 reef act compliant (octinoxate & oxybenzone free) broad spectrum uva/uvb sunscreen  0.53 oz | Sunscreen Cream |
# | neutrogena beach defense water-resistant face & body spf 70 sunscreen lotion with broad spectrum uva/uvb protection oil-free fast-absorbing sunscreen lotion oxybenzone-free 6.7 oz | Sunscreen Lotion |
# | banana boat sport ultra spf 50 lip sunscreen twin pack  spf lip balm pack banana boat lip balm spf 50 oxybenzone free sunscreen lip sunblock travel size sunscreen for lips 2 pack | Lip Balm |
#
# Content of response_df:
#                                        product_title        product_type
# 0   softsoap antibacterial liquid hand soap refil...          Hand Soap
# 1   aquaphor lip repair tubes lip ointment for ch...           Lip Balm
# 2   eltamd uv daily spf 40 tinted face sunscreen ...     Face Sunscreen
# 3   l’oréal paris collagen daily face moisturizer...   Face Moisturizer
# 4   biodance bio-collagen real deep mask hydratin...          Face Mask
# 5   cetaphil face & body moisturizer hydrating mo...   Body Moisturizer
# 6   sun bum kids spf 50 clear sunscreen face stic...    Sunscreen Cream
# 7   neutrogena beach defense water-resistant face...   Sunscreen Lotion
# 8   banana boat sport ultra spf 50 lip sunscreen ...           Lip Balm
#
# Response for Chunk 37:
# | product_title | product_type |
# |---|---|
# | drmtlgy anti-aging tinted moisturizer with spf 46. universal tint. all-in-one light sheer coverage tinted face sunscreen with broad spectrum protection against uva and uvb rays. 1.7 oz | Face Sunscreen |
# | lume acidified body wash - 24 hour odor control - removes odor better than soap - moisturizing formula - formulated without sls or parabens - ob/gyn developed - 8.5 ounce (clean tangerine) | Body Wash |
# | la roche-posay anthelios tinted sunscreen spf 50 ultra-light fluid broad spectrum spf 50 face sunscreen with titanium dioxide mineral universal tint oil-free | Face Sunscreen |
# | aveeno daily moisturizer body lotion for dry skin prebiotic oat fragrance free 18 fl. oz pack of 1 | Body Lotion |
# | mrs. meyer's clean day liquid hand soap refill rainwater 33 oz | Hand Soap |
# | neutrogena ultra sheer body mist spf 70 sunscreen spray broad spectrum uva/uvb protection lightweight non-greasy water resistant body sunscreen mist non-comedogenic 5 oz | Sunscreen Spray |
# | body glide for her anti chafe balm  chafing stick with added emollients  great for dry sensitive skin and/or sensitive areas  use on chest bra butt groin arm and thigh chafing  0.8oz | Anti Chafe |
# | daolyo pimple patches for face 4 size 300 counts acne patches hydrocolloid patches for covering zits and blemishes spot stickers with salicylic acid tea tree oil & calendula oil | Acne Patches |
# | gold bond friction defense stick 1.75 oz. with aloe to soothe comfort & moisturize rough skin | Anti Chafe |
#
# Content of response_df:
#                                        product_title       product_type
# 0   drmtlgy anti-aging tinted moisturizer with sp...    Face Sunscreen
# 1   lume acidified body wash - 24 hour odor contr...         Body Wash
# 2   la roche-posay anthelios tinted sunscreen spf...    Face Sunscreen
# 3   aveeno daily moisturizer body lotion for dry ...       Body Lotion
# 4   mrs. meyer's clean day liquid hand soap refil...         Hand Soap
# 5   neutrogena ultra sheer body mist spf 70 sunsc...   Sunscreen Spray
# 6   body glide for her anti chafe balm  chafing s...        Anti Chafe
# 7   daolyo pimple patches for face 4 size 300 cou...      Acne Patches
# 8   gold bond friction defense stick 1.75 oz. wit...        Anti Chafe

# %%
# Clean and standardize the 'product_title' column in df
df['product_title'] = df['product_title'].apply(clean_title)

# Merge final_df_new with df based on 'product_title'
df = df.merge(final_df_new[['product_title', 'product_type']], on='product_title', how='left')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_title               369 non-null    object
#  1   sales_volume_in_past_month  369 non-null    int64
#  2   product_star_rating         369 non-null    float64
#  3   product_num_ratings         369 non-null    int64
#  4   product_price               369 non-null    float64
#  5   item_form                   369 non-null    object
#  6   special_item_form           369 non-null    object
#  7   product_type_x              1 non-null      object
#  8   product_type_y              251 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 26.1+ KB

# %%
# Drop the 'product_type_x' column
df.drop(columns=['product_type_x'], inplace=True)

# Rename 'product_type_y' to 'product_type'
df.rename(columns={'product_type_y': 'product_type'}, inplace=True)

# Print information about the DataFrame
df.info()

# Save the changes to the DataFrame
df.to_excel('df_with_product_type.xlsx', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_title               369 non-null    object
#  1   sales_volume_in_past_month  369 non-null    int64
#  2   product_star_rating         369 non-null    float64
#  3   product_num_ratings         369 non-null    int64
#  4   product_price               369 non-null    float64
#  5   item_form                   369 non-null    object
#  6   special_item_form           369 non-null    object
#  7   product_type                251 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 23.2+ KB

# %%
import time
from google.api_core.exceptions import TooManyRequests

# Define a function to fill empty cells in 'product_type'
def fill_empty_cells(df):
    # Maximum number of retries
    max_retries = 3
    retry_count = 0

    # Check if there are any empty cells in 'product_type'
    while df['product_type'].isnull().any() and retry_count < max_retries:
        # Get indices of empty cells
        empty_indices = df[df['product_type'].isnull()].index

        # Iterate over empty indices
        for index in empty_indices:
            # Extract the product title from df based on the index
            product_title = df.loc[index, 'product_title']

            # Construct the query for the product title
            query = f"From the title:\n{product_title}\nextract product type, use only one of the following types:\n"
            query += ', '.join(product_types_list)
            query += ". The result must be a single product type."

            # Generate content using Gemini
            try:
                response = model.generate_content(query)
            except TooManyRequests:
                print("Rate limit exceeded. Waiting before retrying...")
                time.sleep(60)  # Wait for 60 seconds before retrying
                continue

            # Extract the product type from the response
            try:
                product_type = response.candidates[0].content.parts[0].text.strip()
            except (IndexError, AttributeError):
                print("Unexpected response format from the generative model.")
                continue

            # Update the dataframe with the generated product type
            df.loc[index, 'product_type'] = product_type

            print(f"Filled empty cell at index {index} with product type: {product_type}")

        # Increment retry count
        retry_count += 1

    return df

# Fill empty cells in 'product_type' of df with retry mechanism
final_df_filled = fill_empty_cells(df)

# Save the changes to the dataframe
final_df_filled.to_excel('final_df_filled.xlsx', index=False)
# Out:
# Filled empty cell at index 27 with product type: Face Toner
# Filled empty cell at index 29 with product type: Face Oil
# Filled empty cell at index 30 with product type: Head Band
# Filled empty cell at index 41 with product type: Face Moisturizer
# Filled empty cell at index 42 with product type: Eye Mask
# Filled empty cell at index 43 with product type: Face Cleanser
# Filled empty cell at index 44 with product type: Face Serum
# Filled empty cell at index 45 with product type: Face Cream
# Filled empty cell at index 46 with product type: Face Serum
# Filled empty cell at index 47 with product type: Skincare Set
# Filled empty cell at index 48 with product type: Skincare Set
# Filled empty cell at index 49 with product type: Anti-aging Serum
# Filled empty cell at index 50 with product type: Face Cream
# Filled empty cell at index 82 with product type: Skincare Set
# Filled empty cell at index 84 with product type: Face Cleanser
# Filled empty cell at index 86 with product type: Body Cream
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 531.83ms
# Rate limit exceeded. Waiting before retrying...
# Filled empty cell at index 88 with product type: Acne Patches
# Filled empty cell at index 89 with product type: Face Mask
# Filled empty cell at index 90 with product type: Face Cleanser
# Filled empty cell at index 91 with product type: Face Foam
# Filled empty cell at index 96 with product type: Beauty Tools
# Filled empty cell at index 102 with product type: Eye Cream
# Filled empty cell at index 103 with product type: Face Cleanser
# Filled empty cell at index 104 with product type: Skincare Set
# Filled empty cell at index 105 with product type: Face Wash
# Filled empty cell at index 106 with product type: Anti-aging Serum
# Filled empty cell at index 107 with product type: Exfoliating Mask
# Filled empty cell at index 108 with product type: Face Serum
# Filled empty cell at index 109 with product type: Face Moisturizer
# Filled empty cell at index 110 with product type: Face Exfoliator
# Filled empty cell at index 111 with product type: Anti-aging Serum
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 657.22ms
# Rate limit exceeded. Waiting before retrying...
# Filled empty cell at index 113 with product type: Lip Mask
# Filled empty cell at index 114 with product type: Face Moisturizer
# Filled empty cell at index 115 with product type: Face Moisturizer
# Filled empty cell at index 116 with product type: Skincare Set
# Filled empty cell at index 117 with product type: Face Scrub
# Filled empty cell at index 118 with product type: Eye Patches
# Filled empty cell at index 119 with product type: Sheet Mask
# Filled empty cell at index 120 with product type: Eye Mask
# Filled empty cell at index 121 with product type: Acne Treatment
# Filled empty cell at index 162 with product type: Face Wash
# Filled empty cell at index 163 with product type: Face Mask
# Filled empty cell at index 164 with product type: Face Serum
# Filled empty cell at index 165 with product type: Kids Care
# Filled empty cell at index 166 with product type: Face Foam
# Filled empty cell at index 167 with product type: Face Moisturizer
# Filled empty cell at index 168 with product type: Anti-aging Cream
# Filled empty cell at index 169 with product type: Face Oil
# Filled empty cell at index 170 with product type: Neck Cream
# Filled empty cell at index 171 with product type: Face Cream
# Filled empty cell at index 172 with product type: Face Serum
# Filled empty cell at index 202 with product type: Face Cleanser
# Filled empty cell at index 203 with product type: Skincare Set
# Filled empty cell at index 204 with product type: Face Mask
# Filled empty cell at index 205 with product type: Face Moisturizer
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 507.19ms
# Rate limit exceeded. Waiting before retrying...
# Filled empty cell at index 207 with product type: Lip Mask
# Filled empty cell at index 208 with product type: Face Mask
# Filled empty cell at index 209 with product type: Face Patches
# Filled empty cell at index 210 with product type: Eye Mask
# Filled empty cell at index 211 with product type: Skincare Set
# Filled empty cell at index 242 with product type: Face Wash
# Filled empty cell at index 243 with product type: Face Serum
# Filled empty cell at index 244 with product type: Face Serum
# Filled empty cell at index 245 with product type: Face Toner
# Filled empty cell at index 246 with product type: Anti-aging Serum
# Filled empty cell at index 247 with product type: Face Wash
# Filled empty cell at index 248 with product type: Face Cream
# Filled empty cell at index 249 with product type: Face Mask
# Filled empty cell at index 250 with product type: Face Exfoliator
# Filled empty cell at index 251 with product type: Face Mask
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 506.48ms
# Rate limit exceeded. Waiting before retrying...
# Filled empty cell at index 283 with product type: Skincare Set
# Filled empty cell at index 284 with product type: Face Wash
# Filled empty cell at index 285 with product type: Face Moisturizer
# Filled empty cell at index 286 with product type: Hair Removal
# Filled empty cell at index 287 with product type: Sheet Mask
# Filled empty cell at index 288 with product type: Face Moisturizer
# Filled empty cell at index 289 with product type: Eye Cream
# Filled empty cell at index 290 with product type: Face Moisturizer
# Filled empty cell at index 291 with product type: Face Moisturizer
# Filled empty cell at index 292 with product type: Scar Cream
# Filled empty cell at index 293 with product type: Exfoliating Mask
# Filled empty cell at index 294 with product type: Body Wash
# Filled empty cell at index 295 with product type: Skincare Set
# Filled empty cell at index 296 with product type: Anti-aging Cream
# Filled empty cell at index 297 with product type: Acne Treatment
# Filled empty cell at index 298 with product type: Hair Care
# Filled empty cell at index 299 with product type: Face Scrub
# Filled empty cell at index 300 with product type: Face Wash
# Filled empty cell at index 301 with product type: Anti-aging Serum
# Filled empty cell at index 302 with product type: Anti-aging Serum
# Filled empty cell at index 303 with product type: Lip Mask
# Filled empty cell at index 304 with product type: Face Wipes
# Filled empty cell at index 305 with product type: Face Wipes
# Filled empty cell at index 306 with product type: Body Soap
# Filled empty cell at index 307 with product type: Acne Patches
# Filled empty cell at index 308 with product type: Face Moisturizer
# Filled empty cell at index 309 with product type: Face Mask
# Filled empty cell at index 310 with product type: Beauty Tools
# Filled empty cell at index 87 with product type: Skincare Set
# Filled empty cell at index 112 with product type: Face Toner
# Filled empty cell at index 206 with product type: Beauty Tools
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 505.68ms
# Rate limit exceeded. Waiting before retrying...
# Filled empty cell at index 282 with product type: Face Moisturizer

# %%
final_df_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_title               369 non-null    object
#  1   sales_volume_in_past_month  369 non-null    int64
#  2   product_star_rating         369 non-null    float64
#  3   product_num_ratings         369 non-null    int64
#  4   product_price               369 non-null    float64
#  5   item_form                   369 non-null    object
#  6   special_item_form           369 non-null    object
#  7   product_type                369 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 23.2+ KB

# %%
# Check if all values in 'product_type' are in product_types_list
all_values_matched = final_df_filled['product_type'].isin(product_types_list).all()

if all_values_matched:
    print("All values in 'product_type' match the values in product_types_list.")
else:
    print("Some values in 'product_type' do not match the values in product_types_list.")
# Out:
# Some values in 'product_type' do not match the values in product_types_list.

# %%
# Find values in 'product_type' that are not in product_types_list
invalid_values = final_df_filled[~final_df_filled['product_type'].isin(product_types_list)]['product_type'].unique()

print("Invalid values in 'product_type':")
print(invalid_values)
# Out:
# Invalid values in 'product_type':
# [' Body Scrub ' ' Beauty Tools ' ' Face Mist ' ' Face Cream '
#  ' Acne Patches ' ' Lip Oil ' ' Face Wash ' ' Face Serum ' ' Body Cream '
#  ' Makeup Remover ' ' Skincare Set ' ' Anti-aging Cream ' ' Lip Mask '
#  ' Face Moisturizer ' ' Body Lotion ' ' Face Toner ' ' Face Cleanser '
#  ' Anti-aging Serum ' ' Face Sunscreen ' ' Body Soap ' ' Sunscreen Cream '
#  ' Face Oil ' ' Face Mask ' ' Eye Patches ' ' Skin Care Set '
#  ' Eye Cream ' ' Acne Treatment ' ' Face Exfoliator ' ' Collagen Powder '
#  ' Sheet Mask ' ' Kids Care ' ' Face Wipes ' ' Hair Care ' ' After Shave '
#  ' Hand Cream ' ' Body Wash ' 'Scar Cream' ' Body Powder '
#  ' Tanning Lotion ' ' Anti Chafe ' ' Lip Balm ' ' Sunscreen Spray '
#  ' Hand Soap ' ' Face Foam ' ' Body Moisturizer ' ' Sunscreen Lotion ']

# %%
# Clean and standardize the 'product_type' column
final_df_filled['product_type'] = final_df_filled['product_type'].str.strip().replace({
    'Skin Care Set': 'Skincare Set',  # Correcting typo
    'Scar Cream': 'Acne Treatment',    # Assuming 'Scar Cream' refers to a type of acne treatment
    'Body Moisturizer': 'Body Lotion', # Assuming 'Body Moisturizer' refers to a type of body lotion
    'Sunscreen Lotion': 'Sunscreen Cream' # Correcting typo
})

# Check if all values in 'product_type' are in product_types_list
all_values_matched = final_df_filled['product_type'].isin(product_types_list).all()

if all_values_matched:
    print("All values in 'product_type' match the values in product_types_list.")
else:
    print("Some values in 'product_type' do not match the values in product_types_list.")

# Find values in 'product_type' that are not in product_types_list
invalid_values = final_df_filled[~final_df_filled['product_type'].isin(product_types_list)]['product_type'].unique()

print("\nInvalid values in 'product_type' after cleaning:")
print(invalid_values)
# Out:
# All values in 'product_type' match the values in product_types_list.
#
# Invalid values in 'product_type' after cleaning:
# []

# %%
# Merge final_df_filled with df based on 'product_title'
df = df.merge(final_df_filled[['product_title', 'product_type']], on='product_title', how='left')

# Display the first few rows of the merged DataFrame
print(df.head())
# Out:
#                                        product_title  \
# 0  under eye patches - 60 pcs - 24k gold eye mask...
# 1  pimple patches for face hydrocolloid acne patc...
# 2  sleeping lip mask nourish & hydrate lip mask w...
# 3  glow recipe pha + bha face toner - skin care t...
# 4  under eye patches (30 pairs) gold eye mask and...
#
#    sales_volume_in_past_month  product_star_rating  product_num_ratings  \
# 0                       20000                  4.2                 8653
# 1                       10000                  4.4                 2053
# 2                        1000                  4.3                  205
# 3                        4000                  4.6                 6075
# 4                       30000                  4.5                 3662
#
#    product_price item_form special_item_form product_type_x product_type_y
# 0           8.99       oil           eye oil    Eye Patches    Eye Patches
# 1           9.99       oil          face oil   Acne Patches   Acne Patches
# 2           4.99      balm         lips balm       Lip Mask       Lip Mask
# 3          16.00     toner        face toner     Face Toner     Face Toner
# 4           9.99      mask          eye mask    Eye Patches    Eye Patches

# %%
# Print the columns of final_df_filled
print("Columns of final_df_filled:")
print(final_df_filled.columns)

# Print the first few rows of final_df_filled
print("\nFirst few rows of final_df_filled:")
print(final_df_filled.head())
# Out:
# Columns of final_df_filled:
# Index(['product_title', 'sales_volume_in_past_month', 'product_star_rating',
#        'product_num_ratings', 'product_price', 'item_form',
#        'special_item_form', 'product_type'],
#       dtype='object')
#
# First few rows of final_df_filled:
#                                        product_title  \
# 0  under eye patches - 60 pcs - 24k gold eye mask...
# 1  pimple patches for face hydrocolloid acne patc...
# 2  sleeping lip mask nourish & hydrate lip mask w...
# 3  glow recipe pha + bha face toner - skin care t...
# 4  under eye patches (30 pairs) gold eye mask and...
#
#    sales_volume_in_past_month  product_star_rating  product_num_ratings  \
# 0                       20000                  4.2                 8653
# 1                       10000                  4.4                 2053
# 2                        1000                  4.3                  205
# 3                        4000                  4.6                 6075
# 4                       30000                  4.5                 3662
#
#    product_price item_form special_item_form  product_type
# 0           8.99       oil           eye oil   Eye Patches
# 1           9.99       oil          face oil  Acne Patches
# 2           4.99      balm         lips balm      Lip Mask
# 3          16.00     toner        face toner    Face Toner
# 4           9.99      mask          eye mask   Eye Patches

# %%
# Check the columns of df
print("Columns of df:")
print(df.columns)

# Check the first few rows of df
print("\nFirst few rows of df:")
print(df.head())
# Out:
# Columns of df:
# Index(['product_title', 'sales_volume_in_past_month', 'product_star_rating',
#        'product_num_ratings', 'product_price', 'item_form',
#        'special_item_form', 'product_type_x', 'product_type_y'],
#       dtype='object')
#
# First few rows of df:
#                                        product_title  \
# 0  under eye patches - 60 pcs - 24k gold eye mask...
# 1  pimple patches for face hydrocolloid acne patc...
# 2  sleeping lip mask nourish & hydrate lip mask w...
# 3  glow recipe pha + bha face toner - skin care t...
# 4  under eye patches (30 pairs) gold eye mask and...
#
#    sales_volume_in_past_month  product_star_rating  product_num_ratings  \
# 0                       20000                  4.2                 8653
# 1                       10000                  4.4                 2053
# 2                        1000                  4.3                  205
# 3                        4000                  4.6                 6075
# 4                       30000                  4.5                 3662
#
#    product_price item_form special_item_form product_type_x product_type_y
# 0           8.99       oil           eye oil    Eye Patches    Eye Patches
# 1           9.99       oil          face oil   Acne Patches   Acne Patches
# 2           4.99      balm         lips balm       Lip Mask       Lip Mask
# 3          16.00     toner        face toner     Face Toner     Face Toner
# 4           9.99      mask          eye mask    Eye Patches    Eye Patches

# %%
# Merge final_df_filled with df based on 'product_title'
df = df.merge(final_df_filled[['product_title', 'product_type']], on='product_title', how='left')

# Display the first few rows of the merged DataFrame
print(df.head())
# Out:
#                                        product_title  \
# 0  under eye patches - 60 pcs - 24k gold eye mask...
# 1  pimple patches for face hydrocolloid acne patc...
# 2  sleeping lip mask nourish & hydrate lip mask w...
# 3  glow recipe pha + bha face toner - skin care t...
# 4  under eye patches (30 pairs) gold eye mask and...
#
#    sales_volume_in_past_month  product_star_rating  product_num_ratings  \
# 0                       20000                  4.2                 8653
# 1                       10000                  4.4                 2053
# 2                        1000                  4.3                  205
# 3                        4000                  4.6                 6075
# 4                       30000                  4.5                 3662
#
#    product_price item_form special_item_form product_type_x product_type_y  \
# 0           8.99       oil           eye oil    Eye Patches    Eye Patches
# 1           9.99       oil          face oil   Acne Patches   Acne Patches
# 2           4.99      balm         lips balm       Lip Mask       Lip Mask
# 3          16.00     toner        face toner     Face Toner     Face Toner
# 4           9.99      mask          eye mask    Eye Patches    Eye Patches
#
#    product_type
# 0   Eye Patches
# 1  Acne Patches
# 2      Lip Mask
# 3    Face Toner
# 4   Eye Patches

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_title               567 non-null    object
#  1   sales_volume_in_past_month  567 non-null    int64
#  2   product_star_rating         567 non-null    float64
#  3   product_num_ratings         567 non-null    int64
#  4   product_price               567 non-null    float64
#  5   item_form                   567 non-null    object
#  6   special_item_form           567 non-null    object
#  7   product_type_x              567 non-null    object
#  8   product_type_y              567 non-null    object
#  9   product_type                567 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 44.4+ KB

# %%
# Drop duplicates based on 'product_title'
df = df.drop_duplicates(subset='product_title', keep='first')

# Drop unnecessary columns 'product_type_y' and 'product_type_x'
df = df.drop(columns=['product_type_y', 'product_type_x'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 357 entries, 0 to 566
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_title               357 non-null    object
#  1   sales_volume_in_past_month  357 non-null    int64
#  2   product_star_rating         357 non-null    float64
#  3   product_num_ratings         357 non-null    int64
#  4   product_price               357 non-null    float64
#  5   item_form                   357 non-null    object
#  6   special_item_form           357 non-null    object
#  7   product_type                357 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 25.1+ KB

# %%
# Save the changes to the dataframe
df.to_excel('final_df_filled.xlsx', index=False)
